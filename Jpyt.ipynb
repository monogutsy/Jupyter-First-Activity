# %% [markdown]
# **LIST** ~~DICTIONARIES~~

# %%
# list=[]

sunny=["rain", "rainbow", "color"]

sunny.append("happy") #add
sunny.remove("happy") #remove
sunny.pop() #remove last item
print(sunny[:1]) #slicing
sunny
# Out:
# ['rain']
# ['rain', 'rainbow']

# %% [markdown]
# **DICTIONARIES** ~~LIST~~

# %%
# dictionary={}
rainy={"ai":"apple", "b2": "bat","c3":"cat"}

# updating dictionary
rainy["b2"]="box"
rainy

# slicing
print(rainy["c3"])
# Out:
# cat
